# %%
#ASSIGNMENT 3

# %%
#Question 1:  Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import requests
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(r'C:\Users\Rishabh Singh\Downloads\chromedriver_win32\chromedriver.exe')
url="https://www.amazon.in/"
driver.get(url)

# %%
# search the user input product
search_bar = driver.find_element(By.ID,"twotabsearchtextbox")    
search_bar.clear()                                               
search_bar.send_keys(input('Enter the product you want to search : '))
driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]/span/input').click()
# Out:
# Enter the product you want to search : laptop

# %%
# question 2 : In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
b_name=[]#Brand name
product_name=[]#Product Name
price=[]#Price
ret_exchange=[]#return/Exchange
exp_delivery=[]#Expected delivery
availability=[]#Availability
product_url=[]
urls=[]
start =1
end= 3
for page in range(start,end):
    p_urls=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a")
    
    for i in p_urls:
        urls.append(i.get_attribute('href'))
    next_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_button.click()

# %%
for i in urls:
    driver.get(i)
    time.sleep(2)
    #scraping data for brand name
    try:
        bran=driver.find_element(By.XPATH,"//a[@id='bylineInfo']")
        b_name.append(bran.text)
    except NoSuchElementException as e:
        b_name.append("--")
    #scraping data for product name
    try:
        prod=driver.find_element(By.XPATH,"//h1[@id='title']/span")
        product_name.append(prod.text)
    except NoSuchElementException as e:
        product_name.append("--")


    #scraping data for price
    try:
        pri=driver.find_element(By.XPATH,"//div[@id='apex_desktop']/div/div/table/tbody/tr[2]/td[2]/span/span[2]")
        price.append(pri.text)
    except NoSuchElementException as e:
        price.append("--")

    #scaping data for return
    try:
        retu=driver.find_element(By.XPATH,"//div[@id='RETURNS_POLICY']/span/div[2]/a")
        ret_exchange.append(retu.text)
    except NoSuchElementException as e:
        ret_exchange.append("--")

     #scraping data for expected delivery
    try:
        deliv=driver.find_element(By.XPATH,"//div[@id='ddmDeliveryMessage']/b")
        exp_delivery.append(deliv.text)
    except NoSuchElementException as e:
        exp_delivery.append("--")

    #scraping data for availability
    try:
        avail=driver.find_element(By.XPATH,"//div[@id='availability']/span")
        availability.append(avail.text)
    except NoSuchElementException as e:
        availability.append("--")
    
            
print(len(availability),len(b_name),len(product_name),len(ret_exchange),len(exp_delivery),len(availability),len(price),len(urls))

#creatig dataframe
df=pd.DataFrame({"Brand Name":b_name,"Product":product_name,"Price":price,"Return/Exchange":ret_exchange,"Expected Delivery":exp_delivery,"Availability":availability})#"Product Url":urls})
df
# Out:
# 27 27 27 27 27 27 27 27
#                         Brand Name  \
# 0             Visit the Acer Store
# 1             Visit the Acer Store
# 2             Visit the Acer Store
# 3               Visit the HP Store
# 4            Visit the Honor Store
# 5           Visit the Lenovo Store
# 6               Visit the HP Store
# 7           Visit the Lenovo Store
# 8           Visit the Lenovo Store
# 9             Visit the ASUS Store
# 10            Visit the Acer Store
# 11            Visit the Acer Store
# 12              Visit the HP Store
# 13           Visit the Honor Store
# 14            Visit the ASUS Store
# 15              Visit the HP Store
# 16            Visit the Acer Store
# 17            Visit the Acer Store
# 18              Visit the HP Store
# 19              Visit the HP Store
# 20            Visit the Acer Store
# 21            Visit the ASUS Store
# 22         Visit the Fujitsu Store
# 23            Visit the Acer Store
# 24  Visit the Amazon Renewed Store
# 25          Visit the Lenovo Store
# 26          Visit the Xiaomi Store
#
#                                               Product    Price  \
# 0   Acer Travelmate Business Laptop Intel Corei3 1...       --
# 1   Acer Extensa Laptop Intel Pentium Quad Core (4...       --
# 2   Acer Aspire Intel Core i5 11th Gen - (16 GB/ 5...       --
# 3   HP 255 G8 Notebook (AMD Ryzen™ 3 3250U/8GB RAM...       --
# 4   Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...       --
# 5   Lenovo V15 Intel Core i3 11th Gen 1115G4 15.6"...       --
# 6   HP 14s, Intel Celeron N4500, 8GB RAM/256GB SSD...       --
# 7   Lenovo IdeaPad Slim 1 Intel Celeron N4020 4th ...       --
# 8   Lenovo IdeaPad Slim 1 AMD Ryzen 3 3250U 15.6" ...       --
# 9   ASUS VivoBook 15 (2021) Intel Core i3-10110U 1...       --
# 10  Acer Aspire 3 Intel Core i5 11th Generation 15...       --
# 11  Acer Aspire 5 Intel Core i5 11th Gen Thin & Li...       --
# 12  HP 15- AMD Ryzen 3-3250U 15.6 inches 39.6 cm F...       --
# 13  Honor MagicBook 15, AMD Ryzen 5 5500U 15.6-inc...       --
# 14  ASUS Vivobook 14, 14.0-inch (35.56 cms) FHD, I...       --
# 15  (Renewed) HP Elitebook Laptop 2560p Intel Core...       --
# 16  Acer Predator Helios 500 Gaming Laptop (11Th G...       --
# 17  Acer Extensa 15 Lightweight Laptop Intel Core ...       --
# 18  HP ProBook 440 G8 Notebook PC, 11th Gen Intel ...       --
# 19  HP 14s-Intel Celeron N4500- 8GB RAM/256GB SSD ...       --
# 20  Acer Extensa 15 Thin & Light Intel Processor P...       --
# 21  ASUS VivoBook 14 (2021), Intel Core i5-1135G7 ...       --
# 22  Fujitsu CH Intel Evo Core i5 11th Gen 13.3” FH...       --
# 23  Acer Travelmate Intel N4020 Celeron Dual-core ...       --
# 24  (Renewed) Lenovo ThinkPad Core 2 Duo HD Busine...  ₹11,999
# 25  (Renewed) Lenovo ThinkPad 6th Gen Intel Core i...       --
# 26  RedmiBook Pro Intel Core i5 11th Gen H Series ...       --
#
#        Return/Exchange Expected Delivery           Availability
# 0   7 days Replacement                --              In stock.
# 1   7 days Replacement                --              In stock.
# 2   7 days Replacement                --              In stock.
# 3   7 days Replacement                --              In stock.
# 4   7 days Replacement                --              In stock.
# 5   7 days Replacement                --              In stock.
# 6   7 days Replacement                --              In stock.
# 7   7 days Replacement                --  Only 1 left in stock.
# 8   7 days Replacement                --              In stock.
# 9   7 days Replacement                --  Only 1 left in stock.
# 10  7 days Replacement                --              In stock.
# 11  7 days Replacement                --              In stock.
# 12  7 days Replacement                --              In stock.
# 13  7 days Replacement                --              In stock.
# 14  7 days Replacement                --              In stock.
# 15  7 days Replacement                --  Only 1 left in stock.
# 16  7 days Replacement                --  Only 1 left in stock.
# 17  7 days Replacement                --              In stock.
# 18  7 days Replacement                --              In stock.
# 19  7 days Replacement                --              In stock.
# 20  7 days Replacement                --  Only 2 left in stock.
# 21  7 days Replacement                --              In stock.
# 22  7 days Replacement                --  Only 2 left in stock.
# 23  7 days Replacement                --              In stock.
# 24   7 days Returnable                --  Only 1 left in stock.
# 25  7 days Replacement                --              In stock.
# 26  7 days Replacement                --              In stock.

# %%
df.to_csv("Scraped File",index=False)
driver.close()

# %%
# question 3 :  Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver = webdriver.Chrome(r'C:\Users\Rishabh Singh\Downloads\chromedriver_win32\chromedriver.exe')
driver.maximize_window()
driver.get('https://images.google.com/')

inp = ['fruits','cars','Machine Learning','Guitar','Cakes'] # input list

#Creating Empty lists
fruits=[]
cars=[]
ML=[]
Guitar=[]
Cakes=[]

lists = [] # list of empty lists

for i in inp:
    try:
        search_bar=driver.find_element(By.XPATH,'//div[@class="YacQv"]') # Finding the search bar using it's xpath
    except NoSuchElementException:
        search_bar=driver.find_element(By.XPATH,'//div[@class="a4bIc"]') # Finding the search bar using it's xpath
        
    
    search_bar.send_keys(i) # Inputing input keyword to search rock images
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [4], in <cell line: 16>()
#      19 except NoSuchElementException:
#      20     search_bar=driver.find_element(By.XPATH,'//div[@class="a4bIc"]') # Finding the search bar using it's xpath
# ---> 23 search_bar.send_keys(i)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:233, in WebElement.send_keys(self, *value)
#     230             remote_files.append(self._upload(file))
#     231         value = "\n".join(remote_files)
# --> 233 self._execute(
#     234     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     235 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
#     409 params["id"] = self._id
# --> 410 return self._parent.execute(command, params)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0036F243]
# 	(No symbol) [0x002F7FD1]
# 	(No symbol) [0x001ECF10]
# 	(No symbol) [0x0021795E]
# 	(No symbol) [0x002170E5]
# 	(No symbol) [0x0023858C]
# 	(No symbol) [0x00212BFF]
# 	(No symbol) [0x00238804]
# 	(No symbol) [0x0024C9EB]
# 	(No symbol) [0x00238386]
# 	(No symbol) [0x0021163C]
# 	(No symbol) [0x0021269D]
# 	GetHandleVerifier [0x00609A22+2655074]
# 	GetHandleVerifier [0x005FCA24+2601828]
# 	GetHandleVerifier [0x00418C0A+619850]
# 	GetHandleVerifier [0x00417830+614768]
# 	(No symbol) [0x003005FC]
# 	(No symbol) [0x00305968]
# 	(No symbol) [0x00305A55]
# 	(No symbol) [0x0031051B]
# 	BaseThreadInitThunk [0x7735FEF9+25]
# 	RtlGetAppContainerNamedObjectPath [0x774A7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x774A7B8E+238]

# %%
# question 4: Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# Connecting to webdriver
driver = webdriver.Chrome(r'C:\Users\Rishabh Singh\Downloads\chromedriver_win32\chromedriver.exe')
driver.maximize_window()

# opening the url
driver.get('https://www.flipkart.com')

#cancelling login window
search_btn = driver.find_element(By.XPATH,'//div[@class="_3OO5Xc"]')
search_btn.click()

# getting the input
search_inp = input("Enter the product: ")

# locating the search bar
search_bar = driver.find_element(By.XPATH,"//input[@class='_3704LK']")
search_bar.send_keys(search_inp)

# locating the search button
search_btn = driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
search_btn.click()
# Out:
# Enter the product: pixel 4a

# %%
# creating Empty variable to store our data:
brand = []
s_name = []
color = []
ram = []
rom = []
p_camera = []
s_camera = []
display_s = []
display_r = []
battery = []
price = []
url = []

# %%
# extracting product name, brand name, colour.
for i in driver.find_elements(By.XPATH,"//div[@class='_4rR01T']"):
    s_name.append(i.text)
    name = s_name[-1].split() #extracting the brand name from the product name
    brand.append(name[0])
    a = s_name[-1][s_name[-1].find("(")+1:s_name[-1].rfind(")")]
    color.append(a.split(',')[0]) #extracting colour from the product name
    
# extracting the ram and rom.
for j in driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[1]"):
    ram.append(j.text.split('|')[0])
    rom.append(j.text.split('|')[1])
    
# extracting primary and secondary camera
for k in driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[3]"):
    if(len(k.text.split('|')) == 2):
        p_camera.append(k.text.split('|')[0])
        s_camera.append(k.text.split('|')[1])
    else:
        p_camera.append(k.text.split('|')[0])
        s_camera.append('--')

# extracting display size and display resolution
for l in driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[2]"):
    s = l.text[l.text.find("(")+1:l.text.rfind(")")]
    display_s.append(s)
    r = l.text[l.text.find(")")+1:]
    display_r.append(r)
        
#extracting battery power.
for n in driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[4]"):
    battery.append(n.text)
    
# extracting price
for o in driver.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']"):
     price.append(o.text)

# extracting url
for p in driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']"):
    url.append(p.get_attribute('href'))

# %%
flipkart = pd.DataFrame({})
flipkart['Brand'] = brand
flipkart['Product description'] = s_name
flipkart['Colour'] = color
flipkart['RAM'] = ram
flipkart['ROM'] = rom
flipkart['Primary Camera'] = p_camera
flipkart['Secondary Camera'] = s_camera
flipkart['Display Size'] = display_s
flipkart['Display Resolution'] = display_r
flipkart['Battery'] = battery
flipkart['Price'] = price
flipkart['Product url'] = url

# %%
flipkart.head()
# Out:
#     Brand                   Product description        Colour        RAM  \
# 0  Google  Google Pixel 4a (Just Black, 128 GB)    Just Black  6 GB RAM
# 1  realme       realme C30 (Denim Black, 32 GB)   Denim Black  2 GB RAM
# 2  realme      realme C30 (Bamboo Green, 32 GB)  Bamboo Green  2 GB RAM
# 3  realme         realme C30 (Lake Blue, 32 GB)     Lake Blue  2 GB RAM
# 4  realme       realme C30 (Denim Black, 32 GB)   Denim Black  3 GB RAM
#
#            ROM       Primary Camera   Secondary Camera Display Size  \
# 0   128 GB ROM  12.2MP Rear Camera    8MP Front Camera    5.81 inch
# 1   32 GB ROM      8MP Rear Camera    5MP Front Camera     6.5 inch
# 2   32 GB ROM      8MP Rear Camera    5MP Front Camera     6.5 inch
# 3   32 GB ROM      8MP Rear Camera    5MP Front Camera     6.5 inch
# 4   32 GB ROM      8MP Rear Camera    5MP Front Camera     6.5 inch
#
#   Display Resolution                       Battery    Price  \
# 0   Full HD+ Display              3140 mAh Battery  ₹31,999
# 1        HD+ Display  5000 mAh Lithium Ion Battery   ₹5,999
# 2        HD+ Display  5000 mAh Lithium Ion Battery   ₹5,999
# 3        HD+ Display  5000 mAh Lithium Ion Battery   ₹5,999
# 4        HD+ Display  5000 mAh Lithium Ion Battery   ₹6,999
#
#                                          Product url
# 0  https://www.flipkart.com/google-pixel-4a-just-...
# 1  https://www.flipkart.com/realme-c30-denim-blac...
# 2  https://www.flipkart.com/realme-c30-bamboo-gre...
# 3  https://www.flipkart.com/realme-c30-lake-blue-...
# 4  https://www.flipkart.com/realme-c30-denim-blac...

# %%
flipkart.to_csv("Oneplus data",index=False)
driver.close()

# %%
#question 5:  Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver = webdriver.Chrome(r'C:\Users\Rishabh Singh\Downloads\chromedriver_win32\chromedriver.exe')
driver.maximize_window()

# opening the url
driver.get('https://www.google.com/maps')

search_inp = input("Enter the city: ")
search_bar = driver.find_element(By.XPATH,"//input[@id='searchboxinput']") # locating search bar
search_bar.send_keys(search_inp)

# locating search button
search_btn = driver.find_element(By.XPATH,"//button[@id='searchbox-searchbutton']")
search_btn.click()

# getting the geospatial co-ordinates from the url
time.sleep(2)
geo = driver.current_url
r = geo[geo.find("@")+1:]
s = r[0:21]
s = s.split(',')
print(f'''Latitude: {s[0]}
Longitude: {s[1]}''')
# Out:
# Enter the city: lucknow
# Latitude: 26.8402688
# Longitude: 81.002496

# %%
# question 6

# %%
#question 7: Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome(r'C:\Users\Rishabh Singh\Downloads\chromedriver_win32\chromedriver.exe')
driver.maximize_window()

driver.get("https://www.digit.in/")

# %%
driver.find_element(By.XPATH,"//div[@class='listing_container']//ul//li[9]").click()
time.sleep(3)

# %%
#Creating empty lists
Laptop_Name = []
Operating_sys = []
Display = []
Processor = []
Memory = []
Weight = []
Dimensions = []
Graph_proc = []
Price = []
# Scraping the data of laptop names
laptop_name= driver.find_elements(By.XPATH,"//div[@class='right-container']/div/a/h3")
for name in laptop_name:
    Laptop_Name.append(name.text)
    
    
#Scraping the data of operating system
try:
    op_sys = driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[1]/div/div")
    for os in op_sys:
        Operating_sys.append(os.text)
except NoSuchElementException:
    pass


#Scraping data of display of the laptop
try:
    display= driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[2]/div/div")
    for disp in display:
        Display.append(disp.text)
except NoSuchElementException:
    pass


#Scraping data of Processor
try:
    processor = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[5]/td[3]")
    for pro in processor:
        Processor.append(pro.text)
except NoSuchElementException:
    pass

#Scraping data of memory
try:
    memory = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")
    for memo in memory:
        Memory.append(memo.text)
except NoSuchElementException:
    pass



#Scraping data of dimensions
try:
    dimension = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
    for dim in dimension:
        Dimensions.append(dim.text)
except NoSuchElementException:
    pass


#Scraping data of Graph processor
try:
    graph = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")
    for gra in graph:
        Graph_proc.append(gra.text)
except NoSuchElementException:
    pass


#Scraping data of price
try:
    price = driver.find_elements(By.XPATH,"//td[@class='smprice']")
    for pri in price:
        Price.append(pri.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = Laptop_Name
Gaming_Laptop['Operating system'] = Operating_sys
Gaming_Laptop['Display'] = Display
Gaming_Laptop['Processor'] = Processor
Gaming_Laptop['Memory'] = Memory
Gaming_Laptop['Dimensions'] = Dimensions
Gaming_Laptop['Graphical Processor'] = Graph_proc
Gaming_Laptop['Price'] = Price
Gaming_Laptop
# Out:
#    Laptop Name    Operating system                      Display  \
# 0          NaN  Windows 11 Home OS  17.3" (3840 x 2160) Display
# 1          NaN  Windows 11 Home OS  17.3" (1920 x 1080) Display
# 2          NaN       Windows 11 OS    16" (2560 x 1600) Display
# 3          NaN  Windows 11 Home OS  16.1" (2560 x 1440) Display
# 4          NaN  Windows 11 Home OS  15.6" (2560 x 1440) Display
# 5          NaN  Windows 11 Home OS  15.6" (1920 x 1080) Display
# 6          NaN  Windows 11 Home OS  16.1" (2560 x 1440) Display
# 7          NaN  Windows 11 Home OS    16" (2560 x 1600) Display
# 8          NaN  Windows 11 Home OS  15.6" (1920 x 1080) Display
# 9          NaN  Windows 11 Home OS         15.6 MP | NA Display
#
#          Processor                       Memory  \
# 0  Windows 11 Home    64 GB DDR5 RAM & 2 TB SSD
# 1  Windows 11 Home    32 GB DDR5 RAM & 1 TB SSD
# 2       Windows 11    32 GB DDR5 RAM & 2 TB SSD
# 3  Windows 11 Home     8 GB DDR5 RAM & 1 TB SSD
# 4  Windows 11 Home  16 GB DDR4 RAM & 512 GB SSD
# 5  Windows 11 Home    16 GB DDR4 RAM & 1 TB SSD
# 6  Windows 11 Home   16 GB DDR4 RAM & 1 TB NVMe
# 7  Windows 11 Home    16 GB DDR5 RAM & 1 TB SSD
# 8  Windows 11 Home  16 GB DDR4 RAM & 512 GB SSD
# 9  Windows 11 Home    16 GB DDR4 RAM & 1 TB SSD
#
#                                           Dimensions  \
# 0        397 x 330 x 23 mm dimension & 3.3 kg weight
# 1       299 x 359 x 21 mm dimension & 2.96 kg weight
# 2        262 x 359 x 20 mm dimension & 2.4 kg weight
# 3       369 x 248 x 23 mm dimension & 2.32 kg weight
# 4      363 x 255 x 23.9 mm dimension & 2.4 kg weight
# 5        357 x 247 x 19 mm dimension & 1.9 kg weight
# 6    36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight
# 7       360 x 264 x 20 mm dimension & 2.49 kg weight
# 8  356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...
# 9        356 x 252 x 16 mm dimension & 1.9 kg weight
#
#                                  Graphical Processor        Price
# 0  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...          N/A
# 1  16 GB DDR6 NVIDIA GEFORCE RTX 3080 Ti Graphics...  Rs  389,990
# 2  8 GB DDR6 NVIDIA GeForce RTX 3070 Ti Graphics ...  Rs  229,990
# 3   8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card  Rs  176,490
# 4    8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card  Rs  172,999
# 5       10 GB DDR6 AMD Radeon RX 6700M Graphics card  Rs  188,990
# 6      8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card  Rs  124,990
# 7    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card  Rs  169,990
# 8    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card  Rs  174,000
# 9  6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card  Rs  131,990

# %%
#question 8: Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
# Connecting to webdriver
driver = webdriver.Chrome(r'C:\Users\Rishabh Singh\Downloads\chromedriver_win32\chromedriver.exe')
driver.maximize_window()

# opening the url
driver.get('https://www.forbes.com/')

# clicking on options
driver.find_element(By.XPATH,'/html/body/div[1]/main/section[8]/div[1]/a').click()

# %%
billionaires=driver.find_element(By.XPATH,'/html/body/div[1]/main/div/section/section[1]/div/div/div[1]/div/div[1]/div[1]/div[2]/a/h2')
billionaires.click()

#all_billionaires=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a')
#all_billionaires.click()

# %%
# Scrapping required details:

#creating empty lists:
Rank = []
Name = []
Net_Worth = []
Age = []
Citizenship = []
Source = []
Industry = []

# Scraping Ranks

try:
    R = driver.find_elements(By.XPATH,'//div[@class="rank"]')
    for i in R:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("-")

#Scraping Names
try:
    N = driver.find_elements(By.XPATH,'//div[@class="personName"]')
    for i in N:
        Name.append(i.text)
except NoSuchElementException:
    Name.append("-")

#Scraping Net Worth
try:
    NW = driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
    for i in NW:
        Net_Worth.append(i.text)
except NoSuchElementException:
    Net_Worth.append("-")
    
#Scraping Age
try:
    A = driver.find_elements(By.XPATH,'//div[@class="age"]')
    for i in A:
        Age.append(i.text)
except NoSuchElementException:
    Age.append("-")

#Scraping country Of Citizenship
try:
    C = driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
    for i in C:
        Citizenship.append(i.text)
except NoSuchElementException:
    Citizenship.append("-")
    
#Scraping Source
try:
    S = driver.find_elements(By.XPATH,'//div[@class="source"]')
    for i in S:
        Source.append(i.text)
except NoSuchElementException:
    Source.append("-")

#Scraping Industry
try:
    I = driver.find_elements(By.XPATH,'//div[@class="category"]')
    for i in I:
        Industry.append(i.text)
except NoSuchElementException:
    Industry.append("-")
    
df = pd.DataFrame({'Rank':Rank,
                   'Name':Name,
                   'Net_Worth':Net_Worth,
                   'Age':Age,
                   'Citizenship':Citizenship,
                   'Source':Source,
                   'Industry':Industry})
df
# Out:
#      Rank                      Name Net_Worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4       Berkshire Hathaway  Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %%
driver.close()

# %%
# question 9 :  Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
# Connecting to webdriver
driver = webdriver.Chrome(r'C:\Users\Rishabh Singh\Downloads\chromedriver_win32\chromedriver.exe')
driver.maximize_window()

# opening the url
driver.get('https://www.youtube.com/')

# Clicking on any Random Video
driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-rich-grid-renderer/div[6]/ytd-rich-grid-row[1]/div/ytd-rich-item-renderer[2]/div/ytd-rich-grid-media/div[1]/div[2]/div[1]/h3/a/yt-formatted-string').click()

# %%
# Pausing the video
driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[1]/div[2]/div/div/ytd-player/div/div/div[33]/div[2]/div[1]/button').click()

# %%
# Scrapping required details:

#Creating Empty Lists
Comment = []
Upvote = []
Time = []

# Scraping Comments 
C = driver.find_elements(By.ID,"content")
for i in C:
    Comment.append(i.text)
    
#Scrapping Upvotes
try:
    U = driver.find_elements(By.XPATH,'//div[@class="yt-spec-touch-feedback-shape yt-spec-touch-feedback-shape--touch-response"]')
    for i in U:
        Upvote.append(i.text)
except NoSuchElementException:
    Upvote.append("-")

#Scrapping when comment was posted 
try:
    T = driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
    for i in T:
        Time.append(i.text)
except NoSuchElementException:
    Time.append("-")

# %%
print(len(Comment),len(Upvote),len(Time))
# Out:
# 76 118 84

# %%
df = pd.DataFrame({'Comments':Comment[:76],
                   'Comment upvote':Upvote[:76],
                   'time when comment was posted':Time[:76]})

df
# Out:
#                                              Comments Comment upvote  \
# 0   IN\nSkip navigation\nSign in\n0:14 / 14:47\n2n...
# 1
# 2
# 3
# 4
# ..                                                ...            ...
# 71  A very crucial partnership between Ashwin and ...
# 72  Ashwin hasn't been valued for what he  deserve...
# 73  Ashwin What a Beauty!! \n39* @ Sydney (Drawn)\...
# 74  ये हुई ना भारतीय टीम वाली बात कोई भी परसथीती म...
# 75
#
#    time when comment was posted
# 0
# 1
# 2
# 3
# 4
# ..                          ...
# 71                  5 hours ago
# 72                   1 hour ago
# 73         4 hours ago (edited)
# 74                  5 hours ago
# 75                  5 hours ago
#
# [76 rows x 3 columns]

# %%
#question 10:  Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Connecting to webdriver
driver = webdriver.Chrome(r'C:\Users\Rishabh Singh\Downloads\chromedriver_win32\chromedriver.exe')
driver.maximize_window()

# opening the url
driver.get('https://www.hostelworld.com/')

# %%
# Enter the location
loc = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/input')

loc.send_keys("London")

# %%
#choosing frist option
driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div').click()
driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[5]').click()

# %%
# Scrapping required details:
Name = []
Distance = []
Rating = []
Reviews = []
Overall = []
Privates = []
Dorms = []
Facilities = []
Property = []

# Scraping Names 
N = driver.find_elements(By.XPATH,'//div[@class="property-name"]')
for i in N:
    Name.append(i.text)
    
#Scrapping distance from city centre
try:
    D = driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
    for i in D:
        Distance.append(i.text)
except NoSuchElementException:
    Distance.append("-")

#Scrapping ratings
try:
    RT = driver.find_elements(By.XPATH,'//div[@class="score"]')
    for i in RT:
        Rating.append(i.text[:][0:3])
except NoSuchElementException:
    Rating.append("-")
    
#Scrapping total reviews
try:
    RV = driver.find_elements(By.XPATH,'//div[@class="keyword"]')
    for i in RV:
        Reviews.append(i.text)
except NoSuchElementException:
    Reviews.append("-")
    
#Scrapping overall reviews
try:
    O = driver.find_elements(By.XPATH,'//div[@class="keyword"]')
    for i in O:
        Overall.append(i.text)
except NoSuchElementException:
    Overall.append("-")
    
#Scrapping privates from price
P = driver.find_elements(By.XPATH,'//div[@class="accommodation-price unavailable"]')
for i in P:
    Privates.append(i.text.replace('No Privates Available','NaN'))
       
#Scrapping Dorms from price
P = driver.find_elements(By.XPATH,'//strong[@class="current"]')
for i in P:
    Dorms.append(i.text.replace('No Dorms Available','NaN'))
    
#Scrapping Facilities
try:
    F = driver.find_elements(By.XPATH,'//div[@class="property-badges"]')
    for i in F:
        Facilities.append(i.text)
except NoSuchElementException:
    Facilities.append("-")
    
#Scrapping property description.
try:
    PD = driver.find_elements(By.XPATH,'//div[@class="property-distance"]')
    for i in PD:
        Property.append(i.text.replace('\n',', '))
except NoSuchElementException:
    Property.append("-")

# %%
print(len(Name),len(Distance),len(Rating),len(Reviews),len(Privates),len(Dorms),len(Facilities),len(Property))
# Out:
# 32 30 32 30 21 39 30 30

# %%
df = pd.DataFrame({'Hostel name':Name[:20],
                   'Distance from city centre':Distance[:20],
                   'Rating':Rating[:20],
                   'Total reviews':Reviews[:20],
                   'Privates from price':Privates[:20],
                   'Dorms from price':Dorms[:20],
                   'Facilities':Facilities[:20],
                   'Property description':Property[:20]})
df
# Out:
#                                 Hostel name  Distance from city centre Rating  \
# 0               Wombat's City Hostel London   - 3.6km from city centre    8.9
# 1                  St Christopher's Village   - 1.8km from city centre    8.0
# 2               Wombat's City Hostel London   - 5.5km from city centre    8.9
# 3                  St Christopher's Village   - 4.3km from city centre    8.0
# 4                   Hostel One Notting Hill   - 5.4km from city centre    9.3
# 5                           Astor Hyde Park     - 3km from city centre    8.7
# 6                      Urbany Hostel London   - 1.7km from city centre    9.2
# 7                          Generator London   - 2.6km from city centre    7.7
# 8         Safestay London Elephant & Castle   - 4.3km from city centre    7.3
# 9               Smart Russell Square Hostel     - 9km from city centre    7.0
# 10                  St Christopher's Camden    - 10km from city centre    8.2
# 11                       No.8 Seven Sisters   - 5.9km from city centre    5.5
# 12             No.8 Willesden Hostel London   - 6.1km from city centre    6.8
# 13  Safestay London Kensington Holland Park   - 4.4km from city centre    7.0
# 14                         NX London Hostel   - 4.2km from city centre    7.5
# 15                  Smart Camden Inn Hostel   - 7.5km from city centre    8.4
# 16                           Phoenix Hostel  - 11.9km from city centre    7.0
# 17             St Christopher's Hammersmith   - 1.7km from city centre    7.7
# 18                       London Backpackers     - 5km from city centre    7.7
# 19              Dover Castle Hostel and Bar   - 5.7km from city centre    8.4
#
#    Total reviews Privates from price Dorms from price  \
# 0       Fabulous                 NaN           ₹3,343
# 1       Fabulous                 NaN           ₹1,786
# 2       Fabulous                 NaN          ₹11,480
# 3       Fabulous                 NaN           ₹3,894
# 4         Superb                 NaN           ₹3,068
# 5       Fabulous                 NaN          ₹13,410
# 6         Superb                 NaN           ₹2,640
# 7      Very Good                 NaN           ₹7,397
# 8      Very Good                 NaN           ₹2,390
# 9      Very Good                 NaN          ₹14,974
# 10      Fabulous                 NaN           ₹3,414
# 11          Good                 NaN           ₹2,256
# 12     Very Good                 NaN           ₹1,951
# 13     Very Good                 NaN             ₹943
# 14      Fabulous                 NaN           ₹1,043
# 15     Very Good                 NaN          ₹10,482
# 16     Very Good                 NaN           ₹3,294
# 17     Very Good                 NaN           ₹1,437
# 18      Fabulous                 NaN           ₹2,165
# 19     Very Good  No Dorms Available           ₹1,793
#
#                               Facilities               Property description
# 0   Follows Covid-19 sanitation guidance   Hostel, - 3.6km from city centre
# 1   Follows Covid-19 sanitation guidance   Hostel, - 1.8km from city centre
# 2                                          Hostel, - 5.5km from city centre
# 3   Follows Covid-19 sanitation guidance   Hostel, - 4.3km from city centre
# 4   Follows Covid-19 sanitation guidance   Hostel, - 5.4km from city centre
# 5   Follows Covid-19 sanitation guidance     Hostel, - 3km from city centre
# 6   Follows Covid-19 sanitation guidance   Hostel, - 1.7km from city centre
# 7   Follows Covid-19 sanitation guidance   Hostel, - 2.6km from city centre
# 8   Follows Covid-19 sanitation guidance   Hostel, - 4.3km from city centre
# 9   Follows Covid-19 sanitation guidance     Hostel, - 9km from city centre
# 10  Follows Covid-19 sanitation guidance    Hostel, - 10km from city centre
# 11                                         Hostel, - 5.9km from city centre
# 12                                         Hostel, - 6.1km from city centre
# 13  Follows Covid-19 sanitation guidance   Hostel, - 4.4km from city centre
# 14  Follows Covid-19 sanitation guidance   Hostel, - 4.2km from city centre
# 15  Follows Covid-19 sanitation guidance   Hostel, - 7.5km from city centre
# 16  Follows Covid-19 sanitation guidance  Hostel, - 11.9km from city centre
# 17                                         Hostel, - 1.7km from city centre
# 18  Follows Covid-19 sanitation guidance     Hostel, - 5km from city centre
# 19                                         Hostel, - 5.7km from city centre

# %%
driver.close()
